# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
path=r"C:\Users\Hi\DATA SCIENCE\Datafiles\Visadataset.csv"

# %%
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path=r"C:\Users\Hi\DATA SCIENCE\Datafiles\bank.csv"

# %%
pd.read_csv(path,
            header=None)
# Out:
#        0              1        2          3        4        5        6     7   \
# 0     age            job  marital  education  default  balance  housing  loan
# 1      30     unemployed  married    primary       no     1787       no    no
# 2      33       services  married  secondary       no     4789      yes   yes
# 3      35     management   single   tertiary       no     1350      yes    no
# 4      30     management  married   tertiary       no     1476      yes   yes
# ...   ...            ...      ...        ...      ...      ...      ...   ...
# 4517   33       services  married  secondary       no     -333      yes    no
# 4518   57  self-employed  married   tertiary      yes    -3313      yes   yes
# 4519   57     technician  married  secondary       no      295       no    no
# 4520   28    blue-collar  married  secondary       no     1137       no    no
# 4521   44   entrepreneur   single   tertiary       no     1136      yes   yes
#
# ...

# %% [markdown]
# # Data framem

# %%
name=['Ramesh','Suresh','Mahesh']
age=(35,39,31)
name,age
# Out:
# (['Ramesh', 'Suresh', 'Mahesh'], (35, 39, 31))

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame(zip(name,age))
# Out:
#         0   1
# 0  Ramesh  35
# 1  Suresh  39
# 2  Mahesh  31

# %% [markdown]
# # Provide Columns

# %%
data=zip(name,age)
pd.DataFrame(data,columns=('Name',"age"))
# Out:
#      Name  age
# 0  Ramesh   35
# 1  Suresh   39
# 2  Mahesh   31

# %% [markdown]
# # Provide Index

# %%
data=zip(name,age)
col=['Name',"age"]
ind=['A','B','C']
pd.DataFrame(data,columns=col,index=ind)
# Out:
#      Name  age
# A  Ramesh   35
# B  Suresh   39
# C  Mahesh   31

# %% [markdown]
# # Add New column

# %%
name=['Ramesh','Suresh','Mahesh']
age=(35,39,31)

data=zip(name,age)
col=['Name',"age"]
ind=['A','B','C']
df=pd.DataFrame(data,columns=col,index=ind)
df
# Out:
#      Name  age
# A  Ramesh   35
# B  Suresh   39
# C  Mahesh   31

# %%
city_name=['hyd','ben','USA']
df['city']=city_name
df
# Out:
#      Name  age city
# A  Ramesh   35  hyd
# B  Suresh   39  ben
# C  Mahesh   31  USA

# %%
# Update existing column

# %%
df['Name']=['Anusha','Merry','Manju']
df
# Out:
#      Name  age city    name
# A  Anusha   35  hyd  Anusha
# B   Merry   39  ben   merry
# C   Manju   31  USA   manju

# %%
df.drop('name',axis=1,inplace=True)
df
# Out:
#      Name  age city
# A  Anusha   35  hyd
# B   Merry   39  ben
# C   Manju   31  USA

# %%
name=['Ramesh','Suresh','Mahesh']
age=(35,39,31)

data=zip(name,age)
col=['Name',"age"]
ind=['A','B','C']
df=pd.DataFrame(data,columns=col,index=ind)

city_name=['hyd','ben','USA']
df['city']=city_name

df.drop('city',axis=1,inplace=True)
df
# Out:
#      Name  age
# A  Ramesh   35
# B  Suresh   39
# C  Mahesh   31

# %%
# drop rows
df.drop('C',axis=0,inplace=True)
df
# Out:
#      Name  age
# A  Ramesh   35
# B  Suresh   39

# %%
df.to_csv("output.csv")

# %%
pd.read_csv("output.csv")
# Out:
#   Unnamed: 0    Name  age
# 0          A  Ramesh   35
# 1          B  Suresh   39

# %%
df.to_csv("output.csv",index=False)

# %%
pd.read_csv("output.csv")
# Out:
#      Name  age
# 0  Ramesh   35
# 1  Suresh   39

# %%
# Creat dataframes using dictionary

d1={"Name":['mahesh','srinu','suman'],
    "Age":[34,57,35]}
pd.DataFrame(d1)
# Out:
#      Name  Age
# 0  mahesh   34
# 1   srinu   57
# 2   suman   35

# %%
path=r"C:\Users\Hi\DATA SCIENCE\Datafiles\Visadataset.csv"
df=pd.read_csv(path)
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # Head Means Top 5 rows

# %%
df.head(2) # deffult 5 rows again we want choose
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified

# %% [markdown]
# # Tail means last 5 rows

# %%
df.tail(2)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25478                 West         86154.77         Year                  Y
# 25479              Midwest         70876.91         Year                  Y
#
#       case_status
# 25478   Certified
# 25479   Certified

# %% [markdown]
# # SHAPE will give number of Rows and Columns

# %%
df.shape
# Out:
# (25480, 12)

# %%
print("the number of rows:",df.shape[0])
print("the number of columns:",df.shape[1])
# Out:
# the number of rows: 25480
# the number of columns: 12

# %% [markdown]
# # SIZE How many indeces are there in given data

# %%
df.size  # 25480*12 = 305760
# Out:
# 305760

# %% [markdown]
# # Columns

# %%
df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# $$dftypes$$
# **Data types**

# %%
df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# $ Task-1 $
#
# **Extract numerical columns and categorical columns separate by using dtypes**

# %%
dict(df.dtypes) # its convert to dictionary
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
d1=dict(df.dtypes)
cat=[i for i in d1 if d1[i]=='object']
num=[i for i in d1 if d1[i]!='object']

# %%
num
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
# Categirical data availble
df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# $ is null $
# ** find out any null values **

# %%
df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
# Drop Duplicate values
df.drop_duplicates()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $info$

# %%
df.info() # every thing will come
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
len(df)
# Out:
# 25480

# %% [markdown]
# $Take-loc-iloc$

# %%
df.take([2,5,7])
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 2  EZYV03           Asia            Bachelor's                  N
# 5  EZYV06           Asia              Master's                  Y
# 7  EZYV08  North America            Bachelor's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                     Y            44444         2008                 West
# 5                     N             2339         2012                South
# 7                     N             3035         1924                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 2      122996.8600         Year                  Y      Denied
# 5       78252.1400         Year                  Y   Certified
# 7         418.2298         Hour                  Y      Denied

# %%
df.iloc[5:10,:] # Specific rows and all the columns
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 5                     N             2339         2012                South
# 6                     N             4985         1994                South
# 7                     N             3035         1924                 West
# 8                     N             4810         2012              Midwest
# 9                     N             2251         1995                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# ...

# %%
df.iloc[:,2:4] # All the rows and specific columns
# Out:
#       education_of_employee has_job_experience
# 0               High School                  N
# 1                  Master's                  Y
# 2                Bachelor's                  N
# 3                Bachelor's                  N
# 4                  Master's                  Y
# ...                     ...                ...
# 25475            Bachelor's                  Y
# 25476           High School                  Y
# 25477              Master's                  Y
# 25478              Master's                  Y
# 25479            Bachelor's                  Y
#
# [25480 rows x 2 columns]

# %%
df.iloc[[100,200,300],[8]]
# Out:
#      prevailing_wage
# 100         28243.79
# 200         74441.11
# 300        101371.21

# %%
df.loc[[100,200,300],['prevailing_wage']]
# Out:
#      prevailing_wage
# 100         28243.79
# 200         74441.11
# 300        101371.21

# %%
path=r"C:\Users\Hi\DATA SCIENCE\Datafiles\Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df.head(3)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %%
visa_df[['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df.continent
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cols=['continent','education_of_employee']
visa_df[cols]
# Out:
#       continent education_of_employee
# 0          Asia           High School
# 1          Asia              Master's
# 2          Asia            Bachelor's
# 3          Asia            Bachelor's
# 4        Africa              Master's
# ...         ...                   ...
# 25475      Asia            Bachelor's
# 25476      Asia           High School
# 25477      Asia              Master's
# 25478      Asia              Master's
# 25479      Asia            Bachelor's
#
# [25480 rows x 2 columns]

# %%
visa_df.values
# Out:
# array([['EZYV01', 'Asia', 'High School', ..., 'Hour', 'Y', 'Denied'],
#        ['EZYV02', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV03', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Denied'],
#        ...,
#        ['EZYV25478', 'Asia', "Master's", ..., 'Year', 'N', 'Certified'],
#        ['EZYV25479', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV25480', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Certified']],
#       dtype=object)

# %%
l1=[1,2,3]
l2=['a','b','c']
l=[l1,l2]
l
pd.DataFrame(l)
# Out:
#    0  1  2
# 0  1  2  3
# 1  a  b  c

# %%
col=['continent']
visa_df[col]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
set(visa_df['continent'].values)
# Out:
# {'Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America'}

# %%
visa_df['continent'].nunique()
# Out:
# 6

# %% [markdown]
# # Find out the only Asia observations

# %%
con=visa_df['continent']=='Asia'
len(visa_df[con])
# Out:
# 16861

# %%
con=visa_df['continent']=='Africa'
len(visa_df[con])
# Out:
# 551

# %%
unique_lable=visa_df['continent'].unique()
for i in unique_lable:
    con=visa_df['continent']==i
    print(i,"-->",len(visa_df[con]))
# Out:
# Asia --> 16861
# Africa --> 551
# North America --> 3292
# Europe --> 3732
# South America --> 852
# Oceania --> 192

# %%
unique_lable=visa_df['continent'].unique()
count=[]
for i in unique_lable:
    con=visa_df['continent']==i
    count.append(len(visa_df[con]))

pd.DataFrame(zip(unique_lable,count),
             columns=['Continent','Count'])
# Out:
#        Continent  Count
# 0           Asia  16861
# 1         Africa    551
# 2  North America   3292
# 3         Europe   3732
# 4  South America    852
# 5        Oceania    192

# %% [markdown]
# # Frequence Table

# %%
unique_lable=visa_df['continent'].unique()
count=[]
for i in unique_lable:
    con=visa_df['continent']==i
    count.append(len(visa_df[con]))

continent_df=pd.DataFrame(zip(unique_lable,count),
                          columns=['Continent','Count'])
continent_df.to_csv('continent_df.csv',index=False)

# %%
continent_df
# Out:
#        Continent  Count
# 0           Asia  16861
# 1         Africa    551
# 2  North America   3292
# 3         Europe   3732
# 4  South America    852
# 5        Oceania    192

# %% [markdown]
# # Value - Counts

# %%
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
continent_vc=visa_df['continent'].value_counts()
continent_vc
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
visa_df
visa_df['continent']
visa_df['continent'].unique()
visa_df['continent'].nunique()
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
continent_vc.keys()
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
continent_vc.values
# Out:
# array([16861,  3732,  3292,   852,   551,   192], dtype=int64)

# %%
continent_vc=visa_df['continent'].value_counts()
l1=continent_vc.keys()
l2=continent_vc.values
pd.DataFrame(zip(l1,l2),columns=['continent','count'])
# Out:
#        continent  count
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 3  South America    852
# 4         Africa    551
# 5        Oceania    192

# %%
unique_lable=visa_df['continent'].unique()
count=[]
for i in unique_lable:
    con=visa_df['continent']==i
    count.append(len(visa_df[con]))
    
continent_df=pd.DataFrame(zip(unique_lable,count),
                          columns=['continent','count'])
continent_df
# Out:
#        continent  count
# 0           Asia  16861
# 1         Africa    551
# 2  North America   3292
# 3         Europe   3732
# 4  South America    852
# 5        Oceania    192

# %%
continent_vc=visa_df['continent'].value_counts() # series
l1=continent_vc.keys()
l2=continent_vc.values
continent_vc_df=pd.DataFrame(zip(l1,l2),
                             columns=['continent','count'])
print(continent_vc_df)
# Out:
#        continent  count
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 3  South America    852
# 4         Africa    551
# 5        Oceania    192

# %%
continent_vc
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
continent_df
# Out:
#        continent  count
# 0           Asia  16861
# 1         Africa    551
# 2  North America   3292
# 3         Europe   3732
# 4  South America    852
# 5        Oceania    192

# %%
continent_vc_df
# Out:
#        continent  count
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 3  South America    852
# 4         Africa    551
# 5        Oceania    192

# %%
plt.figure(figsize=(10,6))
plt.bar('continent',
        'count',
        data=continent_vc_df)
plt.xlabel("continent")
plt.ylabel("count")
plt.title("Bar Chart")
plt.savefig("continent_plt.jpg")
plt.show()

# %%
visa_df['continent'].value_counts().keys()
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
l=visa_df['continent'].value_counts().keys()
sns.countplot(data=visa_df,
              x='continent',
             order=1)
plt.xlabel("continent")
plt.ylabel("count")
plt.title("Bar Chart")
plt.savefig("continent_bar.jpg")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[188], line 3
#       1 plt.figure(figsize=(10,6))
#       2 l=visa_df['continent'].value_counts().keys()
# ----> 3 sns.countplot(data=visa_df,
#       4               x='continent',
#       5              order=1)
#       6 plt.xlabel("continent")
#       7 plt.ylabel("count")
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
# ...

# %%
Q1=np.percentile(visa_df['prevailing_wage'],25)
Q2=np.percentile(visa_df['prevailing_wage'],50)
Q3=np.percentile(visa_df['prevailing_wage'],75)

IQR=Q3-Q1

lb=Q1-1.5*IQR
ub=Q3+1.5*IQR

c1=visa_df['prevailing_wage']<lb
c2=visa_df['prevailing_wage']>ub
con=c1|c2

outliers_df=visa_df[con]
outliers_df
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
# non outliers data

Q1=np.percentile(visa_df['prevailing_wage'],25)
Q2=np.percentile(visa_df['prevailing_wage'],50)
Q3=np.percentile(visa_df['prevailing_wage'],75)

IQR=Q3-Q1

lb=Q1-1.5*IQR
ub=Q3+1.5*IQR

c1=visa_df['prevailing_wage']>lb
c2=visa_df['prevailing_wage']<ub
con=c1&c2

nonoutliers_df=visa_df[c1&c2]
nonoutliers_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
lable=visa_df['continent'].unique()
certi
