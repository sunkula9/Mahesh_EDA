# %% [markdown]
# # Import The packeges and read the Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
df=pd.read_csv(path)
df
# Out:
#       Loan_ID  Gender Married Dependents  ... Loan_Amount_Term Credit_History  Property_Area  Loan_Status
# 0    LP001002    Male      No          0  ...            360.0            1.0          Urban            Y
# 1    LP001003    Male     Yes          1  ...            360.0            1.0          Rural            N
# 2    LP001005    Male     Yes          0  ...            360.0            1.0          Urban            Y
# 3    LP001006    Male     Yes          0  ...            360.0            1.0          Urban            Y
# 4    LP001008    Male      No          0  ...            360.0            1.0          Urban            Y
# ..        ...     ...     ...        ...  ...              ...            ...            ...          ...
# 609  LP002978  Female      No          0  ...            360.0            1.0          Rural            Y
# 610  LP002979    Male     Yes         3+  ...            180.0            1.0          Rural            Y
# ...

# %% [markdown]
# # Head

# %%
df.head()  # by defult we ill get first 5 rows
# Out:
#     Loan_ID Gender Married Dependents  ... Loan_Amount_Term Credit_History  Property_Area  Loan_Status
# 0  LP001002   Male      No          0  ...            360.0            1.0          Urban            Y
# 1  LP001003   Male     Yes          1  ...            360.0            1.0          Rural            N
# 2  LP001005   Male     Yes          0  ...            360.0            1.0          Urban            Y
# 3  LP001006   Male     Yes          0  ...            360.0            1.0          Urban            Y
# 4  LP001008   Male      No          0  ...            360.0            1.0          Urban            Y
#
# [5 rows x 13 columns]

# %% [markdown]
# # Tail

# %%
df.tail()  # by defult we ill get last 5 rows
# Out:
#       Loan_ID  Gender Married Dependents  ... Loan_Amount_Term Credit_History  Property_Area  Loan_Status
# 609  LP002978  Female      No          0  ...            360.0            1.0          Rural            Y
# 610  LP002979    Male     Yes         3+  ...            180.0            1.0          Rural            Y
# 611  LP002983    Male     Yes          1  ...            360.0            1.0          Urban            Y
# 612  LP002984    Male     Yes          2  ...            360.0            1.0          Urban            Y
# 613  LP002990  Female      No          0  ...            360.0            0.0      Semiurban            N
#
# [5 rows x 13 columns]

# %% [markdown]
# # Shape ;- Means find out number of rows and Number of columns

# %%
df.shape
# Out:
# (614, 13)

# %%
print("The number of rows:",df.shape[0])
print("The number of columns:",df.shape[1])
# Out:
# The number of rows: 614
# The number of columns: 13

# %% [markdown]
# # Size:- How many indices are there provided by size

# %%
df.size,614*13
# Out:
# (7982, 7982)

# %% [markdown]
# # Columns

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# # dtypes

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %% [markdown]
# # Extract Numerical columns and categorical column sepearetly by using dtypes output

# %%
d1=dict(df.dtypes)
cat=[i for i in d1 if d1[i]=='object']
num=[i for i in d1 if d1[i]!='object']
cat
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %% [markdown]
# # Include and Exclude Data

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.select_dtypes(exclude='object').columns
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %% [markdown]
# *isnull*

# %% [markdown]
# * identify if data has any missing values or Null values*
# * True means (yes) there is a null value *
# * False maens (No) there is no null value *

# %%
df.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  ...  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# 0      False   False    False       False  ...             False           False          False        False
# 1      False   False    False       False  ...             False           False          False        False
# 2      False   False    False       False  ...             False           False          False        False
# 3      False   False    False       False  ...             False           False          False        False
# 4      False   False    False       False  ...             False           False          False        False
# ..       ...     ...      ...         ...  ...               ...             ...            ...          ...
# 609    False   False    False       False  ...             False           False          False        False
# 610    False   False    False       False  ...             False           False          False        False
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# *Drop Duplicate Values*

# %%
df.drop_duplicates()
# Out:
#       Loan_ID  Gender Married Dependents  ... Loan_Amount_Term Credit_History  Property_Area  Loan_Status
# 0    LP001002    Male      No          0  ...            360.0            1.0          Urban            Y
# 1    LP001003    Male     Yes          1  ...            360.0            1.0          Rural            N
# 2    LP001005    Male     Yes          0  ...            360.0            1.0          Urban            Y
# 3    LP001006    Male     Yes          0  ...            360.0            1.0          Urban            Y
# 4    LP001008    Male      No          0  ...            360.0            1.0          Urban            Y
# ..        ...     ...     ...        ...  ...              ...            ...            ...          ...
# 609  LP002978  Female      No          0  ...            360.0            1.0          Rural            Y
# 610  LP002979    Male     Yes         3+  ...            180.0            1.0          Rural            Y
# ...

# %% [markdown]
# *Info*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
len(df)
# Out:
# 614

# %% [markdown]
# *Take-loc-iloc*

# %%
df.take((2,5,7))
# Out:
#     Loan_ID Gender Married Dependents Education  ... LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# 2  LP001005   Male     Yes          0  Graduate  ...       66.0             360.0             1.0          Urban            Y
# 5  LP001011   Male     Yes          2  Graduate  ...      267.0             360.0             1.0          Urban            Y
# 7  LP001014   Male     Yes         3+  Graduate  ...      158.0             360.0             0.0      Semiurban            N
#
# [3 rows x 13 columns]

# %%
df.take([2,5,7],axis=1) # python index starts with zero.
# Out:
#     Married Self_Employed  CoapplicantIncome
# 0        No            No                0.0
# 1       Yes            No             1508.0
# 2       Yes           Yes                0.0
# 3       Yes            No             2358.0
# 4        No            No                0.0
# ..      ...           ...                ...
# 609      No            No                0.0
# 610     Yes            No                0.0
# 611     Yes            No              240.0
# 612     Yes            No                0.0
# 613      No           Yes                0.0
#
# [614 rows x 3 columns]

# %%
df.take([50,100,150])
# Out:
#       Loan_ID  Gender Married Dependents  ... Loan_Amount_Term Credit_History  Property_Area  Loan_Status
# 50   LP001155  Female     Yes          0  ...            360.0            1.0      Semiurban            Y
# 100  LP001345    Male     Yes          2  ...            180.0            1.0          Urban            Y
# 150  LP001528    Male      No          0  ...            360.0            0.0          Rural            N
#
# [3 rows x 13 columns]

# %%
# Take Does not take rows and columns at a time
df.take([50,100,150]).take([4,8,11],axis=1)
# Out:
#         Education  LoanAmount Property_Area
# 50   Not Graduate       100.0     Semiurban
# 100  Not Graduate       133.0         Urban
# 150      Graduate       118.0         Rural

# %% [markdown]
# *iloc*

# %%
df.iloc[4:10] # ALL THE COLUMNS
# Out:
#     Loan_ID Gender Married Dependents  ... Loan_Amount_Term Credit_History  Property_Area  Loan_Status
# 4  LP001008   Male      No          0  ...            360.0            1.0          Urban            Y
# 5  LP001011   Male     Yes          2  ...            360.0            1.0          Urban            Y
# 6  LP001013   Male     Yes          0  ...            360.0            1.0          Urban            Y
# 7  LP001014   Male     Yes         3+  ...            360.0            0.0      Semiurban            N
# 8  LP001018   Male     Yes          2  ...            360.0            1.0          Urban            Y
# 9  LP001020   Male     Yes          1  ...            360.0            1.0      Semiurban            N
#
# [6 rows x 13 columns]

# %%
df.iloc[4:9,1:3] # ALL ROWS AND COLUMNS
# Out:
#   Gender Married
# 4   Male      No
# 5   Male     Yes
# 6   Male     Yes
# 7   Male     Yes
# 8   Male     Yes

# %%
df.iloc[:,1:3] # ALL THE ROWS
# Out:
#      Gender Married
# 0      Male      No
# 1      Male     Yes
# 2      Male     Yes
# 3      Male     Yes
# 4      Male      No
# ..      ...     ...
# 609  Female      No
# 610    Male     Yes
# 611    Male     Yes
# 612    Male     Yes
# 613  Female      No
#
# [614 rows x 2 columns]

# %%
df.iloc[[50,100,150]]
# Out:
#       Loan_ID  Gender Married Dependents  ... Loan_Amount_Term Credit_History  Property_Area  Loan_Status
# 50   LP001155  Female     Yes          0  ...            360.0            1.0      Semiurban            Y
# 100  LP001345    Male     Yes          2  ...            180.0            1.0          Urban            Y
# 150  LP001528    Male      No          0  ...            360.0            0.0          Rural            N
#
# [3 rows x 13 columns]

# %%
df.iloc[[50,100,150],[4,8,12]]
# Out:
#         Education  LoanAmount Loan_Status
# 50   Not Graduate       100.0           Y
# 100  Not Graduate       133.0           Y
# 150      Graduate       118.0           N

# %%
# only Loan amount
df.iloc[[50,100,150],[8]]
# Out:
#      LoanAmount
# 50        100.0
# 100       133.0
# 150       118.0

# %%
# Only Loan_status
df.iloc[[50,100,150],[12]]
# Out:
#     Loan_Status
# 50            Y
# 100           Y
# 150           N

# %%
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)
loan_df.head(5)
# Out:
#     Loan_ID Gender Married Dependents  ... Loan_Amount_Term Credit_History  Property_Area  Loan_Status
# 0  LP001002   Male      No          0  ...            360.0            1.0          Urban            Y
# 1  LP001003   Male     Yes          1  ...            360.0            1.0          Rural            N
# 2  LP001005   Male     Yes          0  ...            360.0            1.0          Urban            Y
# 3  LP001006   Male     Yes          0  ...            360.0            1.0          Urban            Y
# 4  LP001008   Male      No          0  ...            360.0            1.0          Urban            Y
#
# [5 rows x 13 columns]

# %%
loan_df['Gender'] # Series type
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
loan_df[['Gender']] # Data Frame
# Out:
#      Gender
# 0      Male
# 1      Male
# 2      Male
# 3      Male
# 4      Male
# ..      ...
# 609  Female
# 610    Male
# 611    Male
# 612    Male
# 613  Female
#
# [614 rows x 1 columns]

# %%
loan_df.Gender # Series type
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
loan_df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
# Take want we want to required columns

cols=['Gender','Education']
loan_df[cols]
# Out:
#      Gender     Education
# 0      Male      Graduate
# 1      Male      Graduate
# 2      Male      Graduate
# 3      Male  Not Graduate
# 4      Male      Graduate
# ..      ...           ...
# 609  Female      Graduate
# 610    Male      Graduate
# 611    Male      Graduate
# 612    Male      Graduate
# 613  Female      Graduate
#
# [614 rows x 2 columns]

# %%
loan_df.values
# Out:
# array([['LP001002', 'Male', 'No', ..., 1.0, 'Urban', 'Y'],
#        ['LP001003', 'Male', 'Yes', ..., 1.0, 'Rural', 'N'],
#        ['LP001005', 'Male', 'Yes', ..., 1.0, 'Urban', 'Y'],
#        ...,
#        ['LP002983', 'Male', 'Yes', ..., 1.0, 'Urban', 'Y'],
#        ['LP002984', 'Male', 'Yes', ..., 1.0, 'Urban', 'Y'],
#        ['LP002990', 'Female', 'No', ..., 0.0, 'Semiurban', 'N']],
#       dtype=object)

# %% [markdown]
# *Unique-Lables*

# %%
loan_df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
set(loan_df['Gender'].unique())
# Out:
# {'Female', 'Male', nan}

# %% [markdown]
# *nunique*

# %%
loan_df['Gender'].nunique() # Number of unique elements
# Out:
# 2

# %%
# Q.1 How many Male observations are there?
con=loan_df['Gender']=='Male'
len(loan_df[con])
# Out:
# 489

# %%
unique_lables=loan_df['Gender'].unique()
for i in unique_lables:
    con=loan_df['Gender']==i
    print(i,':',len(loan_df[con]))
# Out:
# Male : 489
# Female : 112
# nan : 0

# %% [markdown]
# *Frequency Table*

# %%
unique_lables=loan_df['Gender'].unique()
count=[]
for i in unique_lables:
    con=loan_df['Gender']==i
    count.append(len(loan_df[con]))
Gender_df=pd.DataFrame(zip(unique_lables,count),
                       columns=['Gender','count'])
Gender_df.to_csv('Gender_df.csv',index=False)
Gender_df
# Out:
#    Gender  count
# 0    Male    489
# 1  Female    112
# 2     NaN      0

# %% [markdown]
# *Value-Counts*

# %%
Gender_ed=loan_df['Gender'].value_counts()
Gender_ed
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
Gender_ed.keys()
# Out:
# Index(['Male', 'Female'], dtype='object', name='Gender')

# %%
Gender_ed.values
# Out:
# array([489, 112], dtype=int64)

# %%
Gender_ed=loan_df['Gender'].value_counts()
l1=Gender_ed.keys()
l2=Gender_ed.values
Gender_ed_df=pd.DataFrame(zip(l1,l2),
                          columns=['Gender','count'])
Gender_ed_df
# Out:
#    Gender  count
# 0    Male    489
# 1  Female    112

# %% [markdown]
# *Bar Chart*

# %%
Gender_ed_df
# Out:
#    Gender  count
# 0    Male    489
# 1  Female    112

# %%
plt.figure(figsize=(4,2))  # plot size
plt.bar('Gender',
        'count',
        data=Gender_ed_df)
plt.xlabel('Gender')
plt.ylabel('count')
plt.title('Bar Chart')
plt.savefig('Gender_ed.jpg')
plt.show()

# %%
Gender_df['Gender'].value_counts().keys()
# Out:
# Index(['Male', 'Female'], dtype='object', name='Gender')

# %%
plt.figure(figsize=(8,4))
l=Gender_df['Gender'].value_counts().keys()
sns.countplot(data=Gender_df,
              x='Gender',
              order=l)
plt.xlabel('Gender')
plt.ylabel('count')
plt.title('Bar Chart')
plt.savefig('Gender_ed.jpg')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)
loan_df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education  ... LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# 0  LP001002   Male      No          0  Graduate  ...        NaN             360.0             1.0          Urban            Y
# 1  LP001003   Male     Yes          1  Graduate  ...      128.0             360.0             1.0          Rural            N
# 2  LP001005   Male     Yes          0  Graduate  ...       66.0             360.0             1.0          Urban            Y
#
# [3 rows x 13 columns]

# %%
values=Gender_df['Gender'].value_counts()
ax=values.plot(kind='bar')
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '1'), Text(0, 0, '1')]

# %%
Gender_df['Gender'].value_counts(normalize=True)
# Out:
# Gender
# Male      0.5
# Female    0.5
# Name: proportion, dtype: float64

# %%
keys=Gender_df['Gender'].value_counts().keys()
values=Gender_df['Gender'].value_counts().values
values
# Out:
# array([1, 1], dtype=int64)

# %%
plt.pie(values,
        labels=keys,
        autopct="%0.3f%%",
        explode=[0.1,0.1],
        startangle=180,
        radius=2)
plt.show()

# %%
loan_df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
loan_df.select_dtypes(exclude='object').columns
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
loan_df['ApplicantIncome']
# Out:
# 0      5849
# 1      4583
# 2      3000
# 3      2583
# 4      6000
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 614, dtype: int64

# %%
len(loan_df['ApplicantIncome'])
# Out:
# 614

# %% [markdown]
# *Count*

# %%
loan_df['ApplicantIncome'].count()
# Out:
# 614

# %% [markdown]
# *Mean*

# %%
loan_df['ApplicantIncome'].mean()
# Out:
# 5403.459283387622

# %%
np.mean(loan_df['ApplicantIncome'])
# Out:
# 5403.459283387622

# %% [markdown]
# *Median*

# %%
loan_df['ApplicantIncome'].median()
# Out:
# 3812.5

# %%
np.median(loan_df['ApplicantIncome'])
# Out:
# 3812.5

# %% [markdown]
# *Max*

# %%
loan_df['ApplicantIncome'].max()
# Out:
# 81000

# %%
np.max(loan_df['ApplicantIncome'])
# Out:
# 81000

# %% [markdown]
# *Min*

# %%
loan_df['ApplicantIncome'].min()
# Out:
# 150

# %%
np.min(loan_df['ApplicantIncome'])
# Out:
# 150

# %% [markdown]
# *Std*

# %%
loan_df['ApplicantIncome'].std()
# Out:
# 6109.041673387174

# %%
incom_count=round(loan_df['ApplicantIncome'].count(),2)
incom_max=round(loan_df['ApplicantIncome'].max(),2)
incom_min=round(loan_df['ApplicantIncome'].min(),2)
incom_mean=round(loan_df['ApplicantIncome'].mean(),2)
incom_median=round(loan_df['ApplicantIncome'].median(),2)
incom_std=round(loan_df['ApplicantIncome'].std(),2)

l=[incom_count,incom_max,incom_min,incom_mean,incom_median,incom_std]
cols=['ApplicantIncome']
index=['count','max','min','mean','median','std']
pd.DataFrame(l,columns=cols,index=index)
# Out:
#         ApplicantIncome
# count            614.00
# max            81000.00
# min              150.00
# mean            5403.46
# median          3812.50
# std             6109.04

# %% [markdown]
# *Percentile-Quantile*

# %%
np.percentile(loan_df['ApplicantIncome'],25)
# Out:
# 2877.5

# %%
np.quantile(loan_df['ApplicantIncome'],0.25)
# Out:
# 2877.5

# %%
con=loan_df['ApplicantIncome'] < 2877.5
len(loan_df[con])
# Out:
# 154

# %%
income_50=np.percentile(loan_df['ApplicantIncome'],50)
con=loan_df['ApplicantIncome']<income_50
len(loan_df[con])
# Out:
# 307

# %%
incom_count=round(loan_df['ApplicantIncome'].count(),2)
incom_max=round(loan_df['ApplicantIncome'].max(),2)
incom_min=round(loan_df['ApplicantIncome'].min(),2)
incom_mean=round(loan_df['ApplicantIncome'].mean(),2)
incom_median=round(loan_df['ApplicantIncome'].median(),2)
incom_std=round(loan_df['ApplicantIncome'].std(),2)
incom_25=np.percentile(loan_df['ApplicantIncome'],25)
incom_50=np.percentile(loan_df['ApplicantIncome'],50)
incom_75=np.percentile(loan_df['ApplicantIncome'],75)
l=[incom_count,incom_max,incom_min,
   incom_mean,incom_median,incom_std,
   incom_25,incom_50,incom_75]
cols=['ApplicantIncome']
index=['count','max','min',
'mean','median','std',
'25%','50%','75%']
pd.DataFrame(l,columns=cols,index=index)
# Out:
#         ApplicantIncome
# count            614.00
# max            81000.00
# min              150.00
# mean            5403.46
# median          3812.50
# std             6109.04
# 25%             2877.50
# 50%             3812.50
# 75%             5795.00

# %%
# All Numerical columns

loan_df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History
# count       614.000000         614.000000  592.000000         600.00000      564.000000
# mean       5403.459283        1621.245798  146.412162         342.00000        0.842199
# std        6109.041673        2926.248369   85.587325          65.12041        0.364878
# min         150.000000           0.000000    9.000000          12.00000        0.000000
# 25%        2877.500000           0.000000  100.000000         360.00000        1.000000
# 50%        3812.500000        1188.500000  128.000000         360.00000        1.000000
# 75%        5795.000000        2297.250000  168.000000         360.00000        1.000000
# max       81000.000000       41667.000000  700.000000         480.00000        1.000000

# %%
# All together
cols=loan_df.select_dtypes(exclude='object').columns
l=[]
for i in cols:
    count=round(loan_df[i].count(),2)
    maxx=round(loan_df[i].max(),2)
    minn=round(loan_df[i].min(),2)
    mean=round(loan_df[i].mean(),2)
    median=round(loan_df[i].median(),2)
    std=round(loan_df[i].std(),2)
    p_25=np.percentile(loan_df[i],25)
    p_50=np.percentile(loan_df[i],50)
    p_75=np.percentile(loan_df[i],75)
    
    l.append([count,maxx,minn,mean,median,
             std,p_25,p_50,p_75])

print(l)
index=['count','max','min',
       'mean','median','std',
       '25%','50%','75%']
pd.DataFrame(zip(l[0],l[1],l[2],l[3],l[4]),columns=cols,index=index)
# Out:
# [[614, 81000, 150, 5403.46, 3812.5, 6109.04, 2877.5, 3812.5, 5795.0], [614, 41667.0, 0.0, 1621.25, 1188.5, 2926.25, 0.0, 1188.5, 2297.25], [592, 700.0, 9.0, 146.41, 128.0, 85.59, nan, nan, nan], [600, 480.0, 12.0, 342.0, 360.0, 65.12, nan, nan, nan], [564, 1.0, 0.0, 0.84, 1.0, 0.36, nan, nan, nan]]
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History
# count            614.00             614.00      592.00            600.00          564.00
# max            81000.00           41667.00      700.00            480.00            1.00
# min              150.00               0.00        9.00             12.00            0.00
# mean            5403.46            1621.25      146.41            342.00            0.84
# median          3812.50            1188.50      128.00            360.00            1.00
# std             6109.04            2926.25       85.59             65.12            0.36
# ...

# %%
cols=loan_df.select_dtypes(exclude='object').columns
d={}
for i in cols:
    count=round(loan_df[i].count(),2)
    maxx=round(loan_df[i].max(),2)
    minn=round(loan_df[i].min(),2)
    mean=round(loan_df[i].mean(),2)
    median=round(loan_df[i].median(),2)
    std=round(loan_df[i].std(),2)
    p_25=np.percentile(loan_df[i],25)
    p_50=np.percentile(loan_df[i],50)
    p_75=np.percentile(loan_df[i],75)
    
    d[i]=[count,maxx,minn,mean,median,
             std,p_25,p_50,p_75]

index=['count','max','min',
       'mean','median','std',
       '25%','50%','75%']
pd.DataFrame(d,index=index)
# Out:
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History
# count            614.00             614.00      592.00            600.00          564.00
# max            81000.00           41667.00      700.00            480.00            1.00
# min              150.00               0.00        9.00             12.00            0.00
# mean            5403.46            1621.25      146.41            342.00            0.84
# median          3812.50            1188.50      128.00            360.00            1.00
# std             6109.04            2926.25       85.59             65.12            0.36
# 25%             2877.50               0.00         NaN               NaN             NaN
# 50%             3812.50            1188.50         NaN               NaN             NaN
# 75%             5795.00            2297.25         NaN               NaN             NaN

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)
loan_df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education  ... LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# 0  LP001002   Male      No          0  Graduate  ...        NaN             360.0             1.0          Urban            Y
# 1  LP001003   Male     Yes          1  Graduate  ...      128.0             360.0             1.0          Rural            N
# 2  LP001005   Male     Yes          0  Graduate  ...       66.0             360.0             1.0          Urban            Y
#
# [3 rows x 13 columns]

# %% [markdown]
# *Histogram*

# %%
f,i,n=plt.hist(loan_df['ApplicantIncome'])

# %%
len(f),len(i),len(n)
# Out:
# (10, 11, 10)

# %%
f
# Out:
# array([533.,  59.,  15.,   0.,   4.,   0.,   1.,   1.,   0.,   1.])

# %%
i
# Out:
# array([  150.,  8235., 16320., 24405., 32490., 40575., 48660., 56745.,
#        64830., 72915., 81000.])

# %%
Between 150 to 8235
we have 533 observations

Between 8235 to 16320
we have 59 observations

# %%
l=150
u=8235
c1=loan_df['ApplicantIncome']>=l
c2=loan_df['ApplicantIncome']<u
c=c1&c2
len(loan_df[c])
# Out:
# 533

# %%
def frquency(l,u):
    c1=loan_df['ApplicantIncome']>=l
    c2=loan_df['ApplicantIncome']<u
    c=c1&c2
    print(len(loan_df[c]))
frquency(8235,16320)
# Out:
# 59

# %%
*Creat a DataFrame
Craeate a dataframe
lower upper frquency
150   8235    533

# %%
lower=[150]
upper=[8235]
frequency=[533]
cols=['lower','upper','frequency']
index=['A']
df=pd.DataFrame(zip(lower,upper,frequency),columns=cols,index=index)
df
# Out:
#    lower  upper  frequency
# A    150   8235        533

# %% [markdown]
# *Box Plot*

# %%
plt.boxplot(loan_df['ApplicantIncome'],
                     vert=False)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)
loan_df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education  ... LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# 0  LP001002   Male      No          0  Graduate  ...        NaN             360.0             1.0          Urban            Y
# 1  LP001003   Male     Yes          1  Graduate  ...      128.0             360.0             1.0          Rural            N
# 2  LP001005   Male     Yes          0  Graduate  ...       66.0             360.0             1.0          Urban            Y
#
# [3 rows x 13 columns]

# %% [markdown]
# *Outlier Analysis*

# %%
Q1=np.percentile(loan_df['ApplicantIncome'],25)
Q2=np.percentile(loan_df['ApplicantIncome'],50)
Q3=np.percentile(loan_df['ApplicantIncome'],75)

IQR=Q3-Q1

lb=Q1-1.5*IQR
ub=Q3+1.5*IQR

c1=loan_df['ApplicantIncome']<lb
c2=loan_df['ApplicantIncome']>ub
c=c1|c2

outlier_df=loan_df[c]
outlier_df
# Out:
#       Loan_ID  Gender Married Dependents  ... Loan_Amount_Term Credit_History  Property_Area  Loan_Status
# 9    LP001020    Male     Yes          1  ...            360.0            1.0      Semiurban            N
# 34   LP001100    Male      No         3+  ...            360.0            1.0          Rural            N
# 54   LP001186  Female     Yes          1  ...            360.0            0.0          Urban            N
# 67   LP001233    Male     Yes          1  ...            360.0            1.0          Urban            Y
# 102  LP001350    Male     Yes        NaN  ...            360.0            1.0          Urban            Y
# 106  LP001369    Male     Yes          2  ...            360.0            1.0          Urban            Y
# 115  LP001401    Male     Yes          1  ...            180.0            1.0          Rural            Y
# 119  LP001422  Female      No          0  ...            360.0            1.0          Urban            Y
# ...

# %% [markdown]
# *Non_Outliers*

# %%
Q1=np.percentile(loan_df['ApplicantIncome'],25)
Q2=np.percentile(loan_df['ApplicantIncome'],50)
Q3=np.percentile(loan_df['ApplicantIncome'],75)

IQR=Q3-Q1

lb=Q1-1.5*IQR
ub=Q3+1.5*IQR

c1=loan_df['ApplicantIncome']>lb
c2=loan_df['ApplicantIncome']<ub
c=c1&c2

non_outlier_df=loan_df[c]
non_outlier_df
# Out:
#       Loan_ID  Gender Married Dependents  ... Loan_Amount_Term Credit_History  Property_Area  Loan_Status
# 0    LP001002    Male      No          0  ...            360.0            1.0          Urban            Y
# 1    LP001003    Male     Yes          1  ...            360.0            1.0          Rural            N
# 2    LP001005    Male     Yes          0  ...            360.0            1.0          Urban            Y
# 3    LP001006    Male     Yes          0  ...            360.0            1.0          Urban            Y
# 4    LP001008    Male      No          0  ...            360.0            1.0          Urban            Y
# ..        ...     ...     ...        ...  ...              ...            ...            ...          ...
# 609  LP002978  Female      No          0  ...            360.0            1.0          Rural            Y
# 610  LP002979    Male     Yes         3+  ...            180.0            1.0          Rural            Y
# ...

# %% [markdown]
# *Compare original data with non outliers data*
#
#    -Will plot histgram and box plot of the both

# %%
plt.hist(loan_df['ApplicantIncome'])
plt.hist(non_outlier_df['ApplicantIncome'])
plt.show()

# %%
plt.boxplot(loan_df['ApplicantIncome'])
plt.boxplot(non_outlier_df['ApplicantIncome'])
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.subplot(2,2,1)
plt.hist(loan_df['ApplicantIncome'],bins=40)
plt.subplot(2,2,2)
plt.boxplot(non_outlier_df['ApplicantIncome'])
plt.subplot(2,2,3)
plt.hist(loan_df['ApplicantIncome'],bins=40)
plt.subplot(2,2,4)
plt.boxplot(non_outlier_df['ApplicantIncome'])
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.subplot(2,2,1).hist(loan_df['ApplicantIncome'],bins=40)
plt.subplot(2,2,2).boxplot(non_outlier_df['ApplicantIncome'])
plt.subplot(2,2,3).hist(loan_df['ApplicantIncome'],bins=40)
plt.subplot(2,2,4).boxplot(non_outlier_df['ApplicantIncome'])
plt.show()

# %% [markdown]
# * How to deal outliers *

# %%
Median_list=[]
median=loan_df['ApplicantIncome'].median()
for i in loan_df['ApplicantIncome']:
    if i<lb or i>ub:
        Median_list.append(median)
    else:
        Median_list.append(i)
len(Median_list)
# Out:
# 614

# %%
# import data packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)
loan_df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education  ... LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# 0  LP001002   Male      No          0  Graduate  ...        NaN             360.0             1.0          Urban            Y
# 1  LP001003   Male     Yes          1  Graduate  ...      128.0             360.0             1.0          Rural            N
# 2  LP001005   Male     Yes          0  Graduate  ...       66.0             360.0             1.0          Urban            Y
#
# [3 rows x 13 columns]

# %%
Q1=np.percentile(loan_df['ApplicantIncome'],25)
Q2=np.percentile(loan_df['ApplicantIncome'],50)
Q3=np.percentile(loan_df['ApplicantIncome'],75)

IQR=Q3-Q1

lb=Q1-1.5*IQR
ub=Q3+1.5*IQR

median=loan_df['ApplicantIncome'].median()

list1=[]

for i in loan_df['ApplicantIncome']:
    if i<lb or i>ub:
        list1.append(median)
    else:
        list1.append(i)
loan_df['ApplicantIncome_New']=list1

# %%
plt.boxplot(loan_df['ApplicantIncome_New'])
plt.show()

# %% [markdown]
# *Np.Where*

# %%
# Read the data again
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)
loan_df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education  ... LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# 0  LP001002   Male      No          0  Graduate  ...        NaN             360.0             1.0          Urban            Y
# 1  LP001003   Male     Yes          1  Graduate  ...      128.0             360.0             1.0          Rural            N
# 2  LP001005   Male     Yes          0  Graduate  ...       66.0             360.0             1.0          Urban            Y
#
# [3 rows x 13 columns]

# %%
# np.where

dict1={'Name':['Mahesh','Ramesh','Rajesh','Suresh'],
       'Num':[1,2,3,4]}
d=pd.DataFrame(dict1)
d
d['Num']>2
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: Num, dtype: bool

# %%
# I want to replace with 500 num which has >2
# other wise keep same number

l=[]
for i in d['Num']:
    if i>2:
        l.append(500)
    else:
        l.append(i)
d['Num']=l
d
# Out:
#      Name  Num
# 0  Mahesh    1
# 1  Ramesh    2
# 2  Rajesh  500
# 3  Suresh  500

# %%
# np.where(con,True,False)

l=np.where(d['Num']>2,500,d['Num'])
d['Num']=l
d
# Out:
#      Name  Num
# 0  Mahesh    1
# 1  Ramesh    2
# 2  Rajesh  500
# 3  Suresh  500

# %% [markdown]
# *Bi Variate analysis*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)
loan_df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education  ... LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# 0  LP001002   Male      No          0  Graduate  ...        NaN             360.0             1.0          Urban            Y
# 1  LP001003   Male     Yes          1  Graduate  ...      128.0             360.0             1.0          Rural            N
# 2  LP001005   Male     Yes          0  Graduate  ...       66.0             360.0             1.0          Urban            Y
#
# [3 rows x 13 columns]

# %% [markdown]
# *Categorical vs Categorical*

# %%
c1=loan_df['Gender']=='Male'
c2=loan_df['Loan_Status']=='Certified'
c3=loan_df['Loan_Status']=='Denied'

cert_con=c1&c2
den_con=c1&c3

certified_count=len(loan_df[cert_con])
denied_count=len(loan_df[den_con])
print(f"there are {certified_count} got certified visa from Gender")
print(f"there are {denied_count} got denied visa from Gender")
# Out:
# there are 0 got certified visa from Gender
# there are 0 got denied visa from Gender

# %%
labels=loan_df['Gender'].unique()

certified_count=[]
denied_count=[]

for i in labels:
    c1=loan_df['Gender']==i
    c2=loan_df['Loan_Status']=='Certified'
    c3=loan_df['Loan_Status']=='Denied'
    
    cert_con=c1&c2
    den_con=c1&c3
    
    certified_count.append(len(loan_df[cert_con]))
    denied_count.append(len(loan_df[den_con]))
    
cols=['Gender','Certified','Denied']
d1=pd.DataFrame(zip(labels,
                 certified_count,
                 denied_count), columns=cols)
d1.set_index('Gender')
# Out:
#         Certified  Denied
# Gender
# Male            0       0
# Female          0       0
# NaN             0       0

# %%
d1.set_index('Gender')
# Out:
#         Certified  Denied
# Gender
# Male            0       0
# Female          0       0
# NaN             0       0

# %% [markdown]
# *Pd.crosstab*

# %%
col1=[loan_df['Gender']]
col2=loan_df['Loan_Status']
result1=pd.crosstab(col1,col2)
result1
# Out:
# Loan_Status    N    Y
# Gender
# Female        37   75
# Male         150  339

# %%
col1=[loan_df['Gender'],
      loan_df['Education']]
col2=loan_df['Loan_Status']
result2=pd.crosstab(col1,col2)
result2
# Out:
# Loan_Status            N    Y
# Gender Education
# Female Graduate       31   61
#        Not Graduate    6   14
# Male   Graduate      105  271
#        Not Graduate   45   68

# %%
result1.plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
result2.plot(kind='bar')
# Out:
# <Axes: xlabel='Gender,Education'>

# %%
col1=[loan_df['Gender'],
      loan_df['Education']]
col2=loan_df['Loan_Status']
result2=pd.crosstab(col2,col1)
result2.plot(kind='bar')
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
col1=loan_df['Gender']
col2=loan_df['Loan_Status']
col3=loan_df['Education']
r1=pd.crosstab(col1, [col2, col3])
r1.plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)
loan_df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education  ... LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# 0  LP001002   Male      No          0  Graduate  ...        NaN             360.0             1.0          Urban            Y
# 1  LP001003   Male     Yes          1  Graduate  ...      128.0             360.0             1.0          Rural            N
# 2  LP001005   Male     Yes          0  Graduate  ...       66.0             360.0             1.0          Urban            Y
#
# [3 rows x 13 columns]

# %% [markdown]
# *Numarical VS Numarical*

# %%
x=[1,2,3,4]
y=[1,2,3,4]

# %% [markdown]
# *plt.scatter*

# %%
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
x=[i for i in range(-4,4)]
y=[i*i for i in x]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
# extract only numerical columns

num_cols=loan_df.select_dtypes(exclude='object')
num_cols.columns
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
# No relation
col1=loan_df['ApplicantIncome']
col2=loan_df['LoanAmount']
plt.scatter(col1,col2)
plt.show()

# %% [markdown]
# *Pearson Correlation Coefficient*

# %%
loan_df.corr(numeric_only=True)
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History
# ApplicantIncome           1.000000          -0.116605    0.570909         -0.045306       -0.014715
# CoapplicantIncome        -0.116605           1.000000    0.188619         -0.059878       -0.002056
# LoanAmount                0.570909           0.188619    1.000000          0.039447       -0.008433
# Loan_Amount_Term         -0.045306          -0.059878    0.039447          1.000000        0.001470
# Credit_History           -0.014715          -0.002056   -0.008433          0.001470        1.000000

# %%
# check the scatter plot between CoapplicantIncome
# with LoanAmount
# we are seeing the relation is 0.188619

col1=loan_df['CoapplicantIncome']
col2=loan_df['LoanAmount']
plt.scatter(col1,col2)
plt.show()

# %% [markdown]
# *heat-map*
#  - visulization of matrix

# %%
corr_loan=loan_df.corr(numeric_only=True)
corr_loan
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History
# ApplicantIncome           1.000000          -0.116605    0.570909         -0.045306       -0.014715
# CoapplicantIncome        -0.116605           1.000000    0.188619         -0.059878       -0.002056
# LoanAmount                0.570909           0.188619    1.000000          0.039447       -0.008433
# Loan_Amount_Term         -0.045306          -0.059878    0.039447          1.000000        0.001470
# Credit_History           -0.014715          -0.002056   -0.008433          0.001470        1.000000

# %%
sns.heatmap(corr_loan,
            annot=True)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)
loan_df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education  ... LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# 0  LP001002   Male      No          0  Graduate  ...        NaN             360.0             1.0          Urban            Y
# 1  LP001003   Male     Yes          1  Graduate  ...      128.0             360.0             1.0          Rural            N
# 2  LP001005   Male     Yes          0  Graduate  ...       66.0             360.0             1.0          Urban            Y
#
# [3 rows x 13 columns]

# %% [markdown]
# *Convert categorical To Numerical*

# %%
# Map Denied and certified

loan_df['Loan_Status'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
d={'Y':0,'N':1}
loan_df['Loan_Status']=loan_df['Loan_Status'].map(d)

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents  ... Loan_Amount_Term Credit_History  Property_Area  Loan_Status
# 0    LP001002    Male      No          0  ...            360.0            1.0          Urban            0
# 1    LP001003    Male     Yes          1  ...            360.0            1.0          Rural            1
# 2    LP001005    Male     Yes          0  ...            360.0            1.0          Urban            0
# 3    LP001006    Male     Yes          0  ...            360.0            1.0          Urban            0
# 4    LP001008    Male      No          0  ...            360.0            1.0          Urban            0
# ..        ...     ...     ...        ...  ...              ...            ...            ...          ...
# 609  LP002978  Female      No          0  ...            360.0            1.0          Rural            0
# 610  LP002979    Male     Yes         3+  ...            180.0            1.0          Rural            0
# ...

# %%
d={}
labels=loan_df['Gender'].unique()
for i in range(len(labels)):
    d[labels[i]]=i
    
loan_df['Gender']=loan_df['Gender'].map(d)
loan_df
# Out:
#       Loan_ID  Gender Married Dependents  ... Loan_Amount_Term Credit_History  Property_Area  Loan_Status
# 0    LP001002       0      No          0  ...            360.0            1.0          Urban            0
# 1    LP001003       0     Yes          1  ...            360.0            1.0          Rural            1
# 2    LP001005       0     Yes          0  ...            360.0            1.0          Urban            0
# 3    LP001006       0     Yes          0  ...            360.0            1.0          Urban            0
# 4    LP001008       0      No          0  ...            360.0            1.0          Urban            0
# ..        ...     ...     ...        ...  ...              ...            ...            ...          ...
# 609  LP002978       1      No          0  ...            360.0            1.0          Rural            0
# 610  LP002979       0     Yes         3+  ...            180.0            1.0          Rural            0
# ...

# %%
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)
cat_col=loan_df.select_dtypes(include='object').columns

d={}
for j in cat_col[1:]:
    labels=loan_df[j].unique()
    for i in range(len(labels)):
        d[labels[i]]=i
    loan_df[j]=loan_df[j].map(d)
    
loan_df
# Out:
#       Loan_ID  Gender  Married  Dependents  ...  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# 0    LP001002       0        0           0  ...             360.0             1.0              0            0
# 1    LP001003       0        1           1  ...             360.0             1.0              1            1
# 2    LP001005       0        1           0  ...             360.0             1.0              0            0
# 3    LP001006       0        1           0  ...             360.0             1.0              0            0
# 4    LP001008       0        0           0  ...             360.0             1.0              0            0
# ..        ...     ...      ...         ...  ...               ...             ...            ...          ...
# 609  LP002978       1        0           0  ...             360.0             1.0              1            0
# ...

# %%
cat_cols=loan_df.select_dtypes(include='object').columns
cat_cols[1:]
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'Property_Area'],
#       dtype='object')

# %%
# Read the data again

path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
loan_df['Loan_Status']=le.fit_transform(loan_df['Loan_Status'])
loan_df
# Out:
#       Loan_ID  Gender Married Dependents  ... Loan_Amount_Term Credit_History  Property_Area  Loan_Status
# 0    LP001002    Male      No          0  ...            360.0            1.0          Urban            1
# 1    LP001003    Male     Yes          1  ...            360.0            1.0          Rural            0
# 2    LP001005    Male     Yes          0  ...            360.0            1.0          Urban            1
# 3    LP001006    Male     Yes          0  ...            360.0            1.0          Urban            1
# 4    LP001008    Male      No          0  ...            360.0            1.0          Urban            1
# ..        ...     ...     ...        ...  ...              ...            ...            ...          ...
# 609  LP002978  Female      No          0  ...            360.0            1.0          Rural            1
# 610  LP002979    Male     Yes         3+  ...            180.0            1.0          Rural            1
# ...

# %%
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)
cat_cols=loan_df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)
cat_cols=loan_df.select_dtypes(include='object').columns
cat_cols
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat_cols:
    loan_df[i]=le.fit_transform(loan_df[i])
loan_df
# Out:
#      Loan_ID  Gender  Married  Dependents  ...  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# 0          0       1        0           0  ...             360.0             1.0              2            1
# 1          1       1        1           1  ...             360.0             1.0              0            0
# 2          2       1        1           0  ...             360.0             1.0              2            1
# 3          3       1        1           0  ...             360.0             1.0              2            1
# 4          4       1        0           0  ...             360.0             1.0              2            1
# ..       ...     ...      ...         ...  ...               ...             ...            ...          ...
# 609      609       0        0           0  ...             360.0             1.0              0            1
# 610      610       1        1           3  ...             180.0             1.0              0            1
# ...

# %%
loan_df['Gender']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 609    0
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Gender, Length: 614, dtype: int32

# %%
loan_df['Gender'].value_counts()
# Out:
# Gender
# 1    489
# 0    112
# 2     13
# Name: count, dtype: int64

# %%
col=loan_df['Gender']

# %%
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)
cat_cols=loan_df.select_dtypes(include='object').columns
cat_cols
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
loan_df['Gender']=le.fit_transform(loan_df['Gender'])
loan_df
# Out:
#       Loan_ID  Gender Married Dependents  ... Loan_Amount_Term Credit_History  Property_Area  Loan_Status
# 0    LP001002       1      No          0  ...            360.0            1.0          Urban            Y
# 1    LP001003       1     Yes          1  ...            360.0            1.0          Rural            N
# 2    LP001005       1     Yes          0  ...            360.0            1.0          Urban            Y
# 3    LP001006       1     Yes          0  ...            360.0            1.0          Urban            Y
# 4    LP001008       1      No          0  ...            360.0            1.0          Urban            Y
# ..        ...     ...     ...        ...  ...              ...            ...            ...          ...
# 609  LP002978       0      No          0  ...            360.0            1.0          Rural            Y
# 610  LP002979       1     Yes         3+  ...            180.0            1.0          Rural            Y
# ...

# %%
le.inverse_transform(loan_df['Gender'])
# Out:
# array(['Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', nan,
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male',
#        'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
# ...

# %% [markdown]
# *np.where*

# %%
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)
con=loan_df['Loan_Status']=='Certified'
loan_df['Loan_Status']=np.where(con,0,1)
loan_df
# Out:
#       Loan_ID  Gender Married Dependents  ... Loan_Amount_Term Credit_History  Property_Area  Loan_Status
# 0    LP001002    Male      No          0  ...            360.0            1.0          Urban            1
# 1    LP001003    Male     Yes          1  ...            360.0            1.0          Rural            1
# 2    LP001005    Male     Yes          0  ...            360.0            1.0          Urban            1
# 3    LP001006    Male     Yes          0  ...            360.0            1.0          Urban            1
# 4    LP001008    Male      No          0  ...            360.0            1.0          Urban            1
# ..        ...     ...     ...        ...  ...              ...            ...            ...          ...
# 609  LP002978  Female      No          0  ...            360.0            1.0          Rural            1
# 610  LP002979    Male     Yes         3+  ...            180.0            1.0          Rural            1
# ...

# %% [markdown]
# *One hot Encoder*
#  - This is says at a time one will on and other will off

# %% [markdown]
# *pd.get_dummies*

# %%
# Read the data
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)
pd.get_dummies(loan_df,
               columns=['Education','Loan_Status'],
               dtype='int')
# Out:
#       Loan_ID  Gender Married Dependents  ... Education_Graduate  Education_Not Graduate  Loan_Status_N  Loan_Status_Y
# 0    LP001002    Male      No          0  ...                  1                       0              0              1
# 1    LP001003    Male     Yes          1  ...                  1                       0              1              0
# 2    LP001005    Male     Yes          0  ...                  1                       0              0              1
# 3    LP001006    Male     Yes          0  ...                  0                       1              0              1
# 4    LP001008    Male      No          0  ...                  1                       0              0              1
# ..        ...     ...     ...        ...  ...                ...                     ...            ...            ...
# 609  LP002978  Female      No          0  ...                  1                       0              0              1
# ...

# %%
# Drop the Loan_Id column
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)
loan_df.drop('Loan_ID',axis=1,inplace=True)
pd.get_dummies(loan_df,
               dtype='int')
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  ...  Property_Area_Urban  Loan_Status_N  Loan_Status_Y
# 0               5849                0.0         NaN  ...                    1              0              1
# 1               4583             1508.0       128.0  ...                    0              1              0
# 2               3000                0.0        66.0  ...                    1              0              1
# 3               2583             2358.0       120.0  ...                    1              0              1
# 4               6000                0.0       141.0  ...                    1              0              1
# ..               ...                ...         ...  ...                  ...            ...            ...
# 609             2900                0.0        71.0  ...                    0              0              1
# 610             4106                0.0        40.0  ...                    0              0              1
# ...

# %% [markdown]
# *Data Standardization*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)
loan_df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education  ... LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# 0  LP001002   Male      No          0  Graduate  ...        NaN             360.0             1.0          Urban            Y
# 1  LP001003   Male     Yes          1  Graduate  ...      128.0             360.0             1.0          Rural            N
# 2  LP001005   Male     Yes          0  Graduate  ...       66.0             360.0             1.0          Urban            Y
#
# [3 rows x 13 columns]

# %%
income=loan_df['ApplicantIncome']
income_mean=loan_df['ApplicantIncome'].mean()
incom_std=loan_df['ApplicantIncome'].std()
nr=income-incom_mean
loan_df['ApplicantIncome_z']=nr/incom_std
loan_df[['ApplicantIncome','ApplicantIncome_z']]
# Out:
#      ApplicantIncome  ApplicantIncome_z
# 0               5849           0.072931
# 1               4583          -0.134303
# 2               3000          -0.393427
# 3               2583          -0.461686
# 4               6000           0.097649
# ..               ...                ...
# 609             2900          -0.409796
# 610             4106          -0.212384
# 611             8072           0.436818
# 612             7583           0.356773
# 613             4583          -0.134303
#
# [614 rows x 2 columns]

# %%
loan_df['ApplicantIncome'].max(),loan_df['ApplicantIncome_z'].max()
# Out:
# (81000, 12.374533362461953)

# %%
loan_df['ApplicantIncome'].min(),loan_df['ApplicantIncome_z'].min()
# Out:
# (150, -0.8599482997285244)

# %%
# The maximum value id is 409.
loan_df['ApplicantIncome'].idxmax(),loan_df['ApplicantIncome_z'].idxmax()
# Out:
# (409, 409)

# %%
# The Minimum value id is 216.
loan_df['ApplicantIncome'].idxmin(),loan_df['ApplicantIncome_z'].idxmin()
# Out:
# (216, 216)

# %%
# Can we get only idxmax and idxmin values.
loan_df.iloc[[409,216]]
# Out:
#       Loan_ID Gender Married Dependents  ... Credit_History Property_Area  Loan_Status  ApplicantIncome_z
# 409  LP002317   Male     Yes         3+  ...            0.0         Rural            N          12.374533
# 216  LP001722   Male     Yes          0  ...            1.0         Rural            N          -0.859948
#
# [2 rows x 14 columns]

# %%
cols=['ApplicantIncome','ApplicantIncome_z']
ids=[409,216]
loan_df[['ApplicantIncome','ApplicantIncome_z']].iloc[[409,216]]
loan_df[cols].iloc[ids]
# Out:
#      ApplicantIncome  ApplicantIncome_z
# 409            81000          12.374533
# 216              150          -0.859948

# %% [markdown]
# *StandardScaler*

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
loan_df['ApplicantIncome_ss']=ss.fit_transform(loan_df[['ApplicantIncome']])

# %%
cols=['ApplicantIncome','ApplicantIncome_z','ApplicantIncome_ss']
loan_df[cols]
# Out:
#      ApplicantIncome  ApplicantIncome_z  ApplicantIncome_ss
# 0               5849           0.072931            0.072991
# 1               4583          -0.134303           -0.134412
# 2               3000          -0.393427           -0.393747
# 3               2583          -0.461686           -0.462062
# 4               6000           0.097649            0.097728
# ..               ...                ...                 ...
# 609             2900          -0.409796           -0.410130
# 610             4106          -0.212384           -0.212557
# 611             8072           0.436818            0.437174
# 612             7583           0.356773            0.357064
# 613             4583          -0.134303           -0.134412
#
# [614 rows x 3 columns]

# %% [markdown]
# *Normalization*

# %%
# Read the data agian
path=r'C:\Users\Hi\DATA SCIENCE\Analyticsvidhya\Loan Prediction data\loan_pred.csv'
loan_df=pd.read_csv(path)

# %%
# x-x_min/(x_max-x_min)

x=loan_df['ApplicantIncome']
x_min=loan_df['ApplicantIncome'].min()
x_max=loan_df['ApplicantIncome'].max()
nr=x-x_min
dr=x_max-x_min
loan_df['ApplicantIncome_norm']=nr/dr

# %%
loan_df['ApplicantIncome_norm'].min(),loan_df['ApplicantIncome_norm'].max()
# Out:
# (0.0, 1.0)

# %% [markdown]
# *MinMaxScaler*

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
loan_df['ApplicantIncome_mms']=mms.fit_transform(loan_df[['ApplicantIncome']])
loan_df['ApplicantIncome_mms']
# Out:
# 0      0.070489
# 1      0.054830
# 2      0.035250
# 3      0.030093
# 4      0.072356
#          ...
# 609    0.034014
# 610    0.048930
# 611    0.097984
# 612    0.091936
# 613    0.054830
# Name: ApplicantIncome_mms, Length: 614, dtype: float64

# %% [markdown]
# *Data Transformation Techniques*

# %%
# Read the required packeges

import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the Exponential-data

exp_data=np.random.exponential(size=10000)
exp_data[:10]
# Out:
# array([5.83083114, 0.16232503, 0.57555734, 0.03837035, 1.02777948,
#        2.57702717, 0.53658094, 0.62682789, 0.76202066, 0.99455885])

# %%
plt.hist(exp_data,bins=30,label='Exponential')
plt.legend()
plt.show()

# %% [markdown]
# *Norm-Data*

# %%
norm_data=np.random.normal(size=1000)
plt.hist(norm_data)
# Out:
# (array([ 17.,  28.,  92., 168., 213., 218., 162.,  69.,  30.,   3.]),
#  array([-2.90048939, -2.30969221, -1.71889504, -1.12809787, -0.5373007 ,
#          0.05349647,  0.64429364,  1.23509081,  1.82588798,  2.41668515,
#          3.00748232]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# *Log Transformation*

# %%
x=2
import numpy as np
np.log(2)
# Out:
# 0.6931471805599453

# %%
log_data=np.log(exp_data)
log_data[:10]
# Out:
# array([ 1.76315955, -1.8181546 , -0.55241642, -3.26047025,  0.02740063,
#         0.94663647, -0.62253786, -0.46708327, -0.27178161, -0.00545601])

# %%
plt.hist(log_data,bins=40,label='Log data')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,
                        bins=40,
                        label='Exponential')
plt.legend()
plt.subplot(1,2,2).hist(exp_data,
                        bins=40,
                        label='Log Transformation')
plt.legend()
plt.show()

# %% [markdown]
# *Reciprocal transformation*

# %%
x=3
np.reciprocal(x)
# Out:
# 0

# %%
# Reciprocal data
rec_data=np.reciprocal(exp_data)
plt.hist(rec_data,bins=40,label='Reciprocal Data')
plt.legend()
plt.show()

# %%
exp_data[:2]
# Out:
# array([5.83083114, 0.16232503])

# %% [markdown]
# *Square root transformation*

# %%
print(25**2) # Square
print(25**(1/2)) # Square root
print(np.sqrt(25))
# Out:
# 625
# 5.0
# 5.0

# %%
sqrt_data=np.sqrt(exp_data)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,
                        bins=40,
                        label='Exponential')
plt.legend()
plt.subplot(1,2,2).hist(sqrt_data,
                        bins=40,
                        label='Squre root transformation')
plt.legend()
plt.show()

# %%
import seaborn as sns
sns.displot(sqrt_data)
# Out:
# C:\Users\Hi\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# *Power Transformer*

# %%
exp_data
# Out:
# array([5.83083114, 0.16232503, 0.57555734, ..., 0.67483796, 0.20550187,
#        2.07079669])

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
pt_data=pt.fit([exp_data]).transform([exp_data])
pt_data
# Out:
# array([[0.00000000e+00, 2.77555756e-17, 1.11022302e-16, ...,
#         0.00000000e+00, 2.77555756e-17, 0.00000000e+00]])

# %%
plt.hist(pt_data[0])
plt.show()

# %% [markdown]
# *Missing Value Analysis*

# %%
import numpy as np
import pandas as pd

# %%
dict1={'Name':['Ramesh','Mahesh',np.nan,'Anil'],
       'Age':[31,32,33,np.nan],
       'City':[np.nan,'Hyd','Mumbai','Chennai']}

# %%
data1=pd.DataFrame(dict1)

# %%
data1.isnull()
# Out:
#     Name    Age   City
# 0  False  False   True
# 1  False  False  False
# 2   True  False  False
# 3  False   True  False

# %%
data1.isnull().sum() # Every column has one missing value is there
# Out:
# Name    1
# Age     1
# City    1
# dtype: int64

# %%
data1.isnull().sum()/len(data1)
# Out:
# Name    0.25
# Age     0.25
# City    0.25
# dtype: float64

# %%
data1.isnull().sum()*100/len(data1)
# Out:
# Name    25.0
# Age     25.0
# City    25.0
# dtype: float64

# %%
dict2={'Name':['Mahesh','Suresh',None,'Ramesh'],
       'Age':[31,32,33,None],
       'City':[None,'Hyd','Mumbai','Chennai']}
data2=pd.DataFrame(dict2)
data2
# Out:
#      Name   Age     City
# 0  Mahesh  31.0     None
# 1  Suresh  32.0      Hyd
# 2    None  33.0   Mumbai
# 3  Ramesh   NaN  Chennai

# %%
data2.isnull()
# Out:
#     Name    Age   City
# 0  False  False   True
# 1  False  False  False
# 2   True  False  False
# 3  False   True  False

# %%
data2.isnull().sum()
# Out:
# Name    1
# Age     1
# City    1
# dtype: int64

# %%
dict3={'Name':['Ramesh','Suresh','Null','Mahesh'],
       'Age':[23,24,26,'Null'],
       'City':['Null','Hyd','Mumbai','Chennai']}
data3=pd.DataFrame(dict3)
data3
# Out:
#      Name   Age     City
# 0  Ramesh    23     Null
# 1  Suresh    24      Hyd
# 2    Null    26   Mumbai
# 3  Mahesh  Null  Chennai

# %% [markdown]
# $METHOD-1$
#  - Fill the missing values with random number
#     - Method Name:fillna

# %%
data1.fillna(20)
# Out:
#      Name   Age     City
# 0  Ramesh  31.0       20
# 1  Mahesh  32.0      Hyd
# 2      20  33.0   Mumbai
# 3    Anil  20.0  Chennai

# %% [markdown]
# $METHOD-2$
#   - Fill the missing values with random number on specific column
#      - Method Name:fillna

# %%
data1['Name'].fillna('Sathish',inplace=True)
data1
# Out:
#       Name   Age     City
# 0   Ramesh  31.0      NaN
# 1   Mahesh  32.0      Hyd
# 2  Sathish  33.0   Mumbai
# 3     Anil   NaN  Chennai
